# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
import copy
import random
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
import random

# %%
df= pd.read_csv("Ranking.csv")

# %%
df_1=df.drop(columns=['Unnamed: 0', 'index','ID'])
#df_1=df_1.dropna()
df_1=df_1.reset_index()

# %%
df_1.head(30)
# Out:
#     index                                               Text   Domain  \
# 0       0         2020 NBA Offseason Preview: Boston Celtics   Sports
# 1       1  AMERICAN MILITARY NEWS reported: Videos: Prote...   Sports
# 2       2  NBA 2K21 Introduces The City For Next-Gen Cons...   Sports
# 3       3  Congrats to user davrogbro62 for winning the t...   Sports
# 4       4  Check out 1972 Topps Baseball Lot  @eBay@sport...   Sports
# 5       5  LeBron James rompe la red para hundir a Stephe...   Sports
# 6       6  Your daily reminder that there is still plenty...   Sports
# 7       7  Sports team officials are funneling hundreds o...   Sports
# 8       8   He got NBA mentality for sure!Was select All-...   Sports
# 9       9                       Latest On The NBA Salary Cap   Sports
# 10     10  Freshmen Baseball Players Impressing in Fall P...   Sports
# 11     11    Marvin Williams 📻🎙️ #YouFirstSports #TeamTandem   Sports
# ...

# %%
df_1['Ranking'][2].toarray()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-8d45ecb8c2e3> in <module>()
# ----> 1 df_1['Ranking'][2].toarray()
#
# AttributeError: 'str' object has no attribute 'toarray'

# %%
df_2=pd.DataFrame(columns=['Text','Content','URL'])
for i in range(98):
    for j in range(98):
        new_row={'Text':df_1['Text'][i],'Content':df_1['Content'][j],'URL':df_1['URL'][j]}
        df_2=df_2.append(new_row, ignore_index=True)

# %%
df_2
# Out:
#                                                    Text  \
# 0            2020 NBA Offseason Preview: Boston Celtics
# 1            2020 NBA Offseason Preview: Boston Celtics
# 2            2020 NBA Offseason Preview: Boston Celtics
# 3            2020 NBA Offseason Preview: Boston Celtics
# 4            2020 NBA Offseason Preview: Boston Celtics
# ...                                                 ...
# 9599  "A feel for the Game" Washington Post PS5 Cern...
# 9600  "A feel for the Game" Washington Post PS5 Cern...
# 9601  "A feel for the Game" Washington Post PS5 Cern...
# 9602  "A feel for the Game" Washington Post PS5 Cern...
# 9603  "A feel for the Game" Washington Post PS5 Cern...
#
#                                                 Content  \
# 0     Hoops Rumors is previewing the 2020 offseason ...
# 1     The situation remained tense in Washington, DC...
# 2                                                   NaN
# 3     Features of PennantChase.comMost users play in...
# ...

# %%
df_2.to_csv("Ranking_expanded.csv",encoding='utf-8-sig')
